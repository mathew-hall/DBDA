# %%
model_A <- function(x)rep(1/4,length(x))
model_B <- function(x)x/10
model_C <- function(x)12/(25*x)

# %%
x <- c(1,2,3,4)
plot(x,model_A(x))
lines(x,model_B(x))
lines(x,model_C(x))
# Out:
# plot without title
